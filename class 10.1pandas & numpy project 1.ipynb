# %% [markdown]
# # (1) PROJECT :- Check for null values in the dataset and visualize them using Pandas, NumPy, Matplotlib, and Seaborn.

# %%
# Import the Pandas library for data manipulation and analysis.
# Import the NumPy library for numerical operations and arrays.

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv (r"C:\Users\ARPIT\Downloads\HDFC loan dataset (2)\HDFC loan dataset\Loan payments data.csv")

# %%
# Display the first 10 rows of the dataset.

# %%
 dataset.head(10)
# Out:
#        Loan_ID loan_status  Principal  terms effective_date   due_date  \
# 0  xqd20166231     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 1  xqd20168902     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 2  xqd20160003     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 3  xqd20160004     PAIDOFF       1000     15       9/8/2016  9/22/2016
# 4  xqd20160005     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 5  xqd20160706     PAIDOFF        300      7       9/9/2016  9/15/2016
# 6  xqd20160007     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 7  xqd20160008     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 8  xqd20160909     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 9  xqd20160010     PAIDOFF        800     15      9/10/2016  9/24/2016
#
#      paid_off_time  past_due_days  age             education  Gender
# 0  9/14/2016 19:31            NaN   45  High School or Below    male
# ...

# %%
# Display the last rows of the dataset.

# %%
dataset.tail()
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# 495  10/11/2016  10/14/2016 19:08            3.0   28  High School or Below
# 496   9/26/2016  10/10/2016 20:02           14.0   26  High School or Below
# 497   9/26/2016   9/29/2016 11:49            3.0   30               college
# 498  11/10/2016  11/11/2016 22:40            1.0   38               college
# 499  10/11/2016  10/19/2016 11:58            8.0   28  High School or Below
#
#      Gender
# 495    male
# 496    male
# 497    male
# 498  female
# 499    male

# %%
 # check how many row and columns in dataset.

# %%
dataset.shape
# Out:
# (500, 11)

# %%
# show null values in dataset  (TRUE MEANS NULL\FAlSE MEANS VALUES IN ROW OR COLUMNS)

# %%
dataset.isnull()
# Out:
#      Loan_ID  loan_status  Principal  terms  effective_date  due_date  \
# 0      False        False      False  False           False     False
# 1      False        False      False  False           False     False
# 2      False        False      False  False           False     False
# 3      False        False      False  False           False     False
# 4      False        False      False  False           False     False
# ..       ...          ...        ...    ...             ...       ...
# 495    False        False      False  False           False     False
# 496    False        False      False  False           False     False
# 497    False        False      False  False           False     False
# 498    False        False      False  False           False     False
# 499    False        False      False  False           False     False
#
#      paid_off_time  past_due_days    age  education  Gender
# 0            False           True  False      False   False
# ...

# %%
# Count the number of missing (null) values in each column

# %%
dataset.isnull().sum()
# Out:
# Loan_ID             0
# loan_status         0
# Principal           0
# terms               0
# effective_date      0
# due_date            0
# paid_off_time     100
# past_due_days     300
# age                 0
# education           0
# Gender              0
# dtype: int64

# %%
# show hou may roes in dataset

# %%
dataset.shape[0]
# Out:
# 500

# %%
# show how many columns in dataset

# %%
dataset.shape[1]
# Out:
# 11

# %%
# Calculate the percentage of missing (null) values in each column.

# %%
dataset.isnull().sum()/dataset.shape[0]*100
# Out:
# Loan_ID            0.0
# loan_status        0.0
# Principal          0.0
# terms              0.0
# effective_date     0.0
# due_date           0.0
# paid_off_time     20.0
# past_due_days     60.0
# age                0.0
# education          0.0
# Gender             0.0
# dtype: float64

# %%
# Calculate the overall percentage of missing values in the entire dataset.

# %%
(dataset.isnull().sum().sum()/(dataset.shape[0]*dataset.shape[1]))*100
# Out:
# np.float64(7.2727272727272725)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(dataset.isnull())
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
